# %% [markdown]
# Print Statement

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Variables: is a thing that can hold a value that can change over time. that why the name as variables.
#
#  Name of the variable called an Identifier.

# %%
wallet = 5000
print(wallet)
wallet = 40
print(wallet)

day = 21
print(day)
# Out:
# 5000
# 40
# 21

# %% [markdown]
# Number Type: this holds intergers or float numbers

# %%
day = 21
temp = -15
weight = 45.454

print(day+3)
print(weight*3)
# Out:
# 24
# 136.362

# %% [markdown]
# String: is collection of albhabets.

# %%
shirt = "blue"
store = "shirt store"

print(store)

#put the name or movie
movie = "the Family man 3"
print(movie)
# Out:
# shirt store
# the Family man 3

# %% [markdown]
# Dynamic String: fstring

# %%
day = "Monday"
print(f"Today is {day}")
# Out:
# Today is Monday

# %% [markdown]
# Boolean: TRUE or FALSE

# %%
light=True
if light:
    print("light is on")
else:
    print("The light if off")
# Out:
# light is on

# %%
weight = 123.56
print(f"Weight is {weight} :)")
# Out:
# Weight is 123.56 :)

# %%
age = 13
if age >= 18:
    print(f"Age is eligible for voting. Age is {age}")
else:
    print(f"Age is not eligible for voting.")
# Out:
# Age is not eligible for voting.
